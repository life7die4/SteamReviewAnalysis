# %%
import requests
import pandas as pd
import json
import re
from collections import Counter
from konlpy.tag import Okt
from nltk.tokenize import TreebankWordTokenizer
from nltk.corpus import stopwords
import nltk
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import os

# 워드클라우드 폰트 경로 설정 (한글 지원용)
FONT_PATH = "C:/Windows/Fonts/malgun.ttf"  # 윈도우 기준

# 1. 리뷰 가져오기
def fetch_steam_reviews(appid, language='all', count=100):
    url = f'https://store.steampowered.com/appreviews/{appid}?json=1'
    params = {
        'filter': 'all',
        'language': language,
        'review_type': 'all',
        'num_per_page': count
    }
    response = requests.get(url, params=params)
    if response.status_code == 200:
        return response.json()
    return None

# 2. 리뷰 CSV 저장
def save_reviews_to_csv(appid):
    languages = {'korean': 100, 'english': 100}
    all_reviews = []

    for lang, count in languages.items():
        data = fetch_steam_reviews(appid, language=lang, count=count)
        if data and 'reviews' in data:
            for review in data['reviews']:
                all_reviews.append({
                    'recommendationid': review.get('recommendationid', ''),
                    'author_steamid': review.get('author', {}).get('steamid', 'Anonymous'),
                    'author_num_games_owned': review.get('author', {}).get('num_games_owned', 0),
                    'author_num_reviews': review.get('author', {}).get('num_reviews', 0),
                    'author_playtime_forever': review.get('author', {}).get('playtime_forever', 0),
                    'author_playtime_last_two_weeks': review.get('author', {}).get('playtime_last_two_weeks', 0),
                    'author_playtime_at_review': review.get('author', {}).get('playtime_at_review', 0),
                    'language': review.get('language', ''),
                    'review': review.get('review', ''),
                    'timestamp_created': review.get('timestamp_created', ''),
                    'voted_up': review.get('voted_up', False),
                    'votes_up': review.get('votes_up', 0),
                    'votes_funny': review.get('votes_funny', 0),
                    'weighted_vote_score': review.get('weighted_vote_score', ''),
                    'comment_count': review.get('comment_count', 0),
                    'steam_purchase': review.get('steam_purchase', False),
                })
    filename = f"../Output/steam_reviews_{appid}.csv"
    df = pd.DataFrame(all_reviews)
    df.to_csv(filename, index=False, encoding='utf-8-sig')
    print(f"Saved {len(df)} reviews to {filename}")
    return filename

# 3. load_stopwords() 함수
def load_stopwords(filepath):
    if not os.path.exists(filepath):
        print(f"[경고] 불용어 파일이 존재하지 않습니다: {filepath}")
        return set()
    
    with open(filepath, 'r', encoding='utf-8') as f:
        stopwords = set([line.strip() for line in f if line.strip()])
    return stopwords


# 3. 키워드 추출 함수 (갯수 조절 가능)
def extract_keywords(text, is_korean=False, custom_stopwords=None, top_n=20, extra_stopwords=None):
    if is_korean:
        okt = Okt()
        words = okt.nouns(text)

        if custom_stopwords is None:
            custom_stopwords = load_stopwords("../Data/stopwords-ko.txt")

        if extra_stopwords:
            print(f"Extra Korean stopwords: {extra_stopwords}")  # 추가된 불용어 확인
            custom_stopwords.update(extra_stopwords)

        words = [word for word in words if word not in custom_stopwords]

    else:
        tokenizer = TreebankWordTokenizer()
        words = tokenizer.tokenize(text)
        words = [word.lower() for word in words if word.isalnum()]

        if custom_stopwords is None:
            custom_stopwords = load_stopwords("../Data/stopwords-en.txt")

        if extra_stopwords:
            print(f"Extra English stopwords: {extra_stopwords}")  # 추가된 불용어 확인
            custom_stopwords.update(extra_stopwords)

        words = [word for word in words if word not in custom_stopwords]

    print(f"Number of words after stopword filtering: {len(words)}")
    return Counter(words).most_common(top_n)


# 4. 리뷰에서 언어별 키워드 추출
def process_reviews_for_keywords(csv_file, top_n=20,
                                  custom_stopwords=None,
                                  extra_korean_stopwords=None,
                                  extra_english_stopwords=None):
    
    df = pd.read_csv(csv_file)
    # 'koreana'를 'korean'으로 변환
    df['language'] = df['language'].replace('koreana', 'korean')
    keyword_results = []

    for lang in ['korean', 'english']:
        is_korean = (lang == 'korean')
        texts = ' '.join(df[df['language'] == lang]['review'].dropna())

        # extra_stopwords는 언어별로 다르게 전달
        extra = extra_korean_stopwords if is_korean else extra_english_stopwords

        keywords = extract_keywords(
            texts,
            is_korean=is_korean,
            custom_stopwords=custom_stopwords,
            top_n=top_n,
            extra_stopwords=extra
        )

        keyword_results.append({
            'language': lang,
            'keywords': keywords
        })

    return keyword_results


# 5. 워드클라우드 생성 및 저장
def generate_wordcloud(keywords, language):
    word_dict = dict(keywords)
    wc = WordCloud(
        font_path=FONT_PATH,
        background_color=None, # 'white'
        colormap='Set2',
        mode='RGBA',
        width=800,
        height=400
    ).generate_from_frequencies(word_dict)

    csv_output_path = f"../Output/keyword_freq_{language}.csv"
    pd.DataFrame(keywords, columns=['word', 'frequency']).to_csv(csv_output_path, index=False, encoding='utf-8-sig')
    print(f"{language} 키워드 빈도 CSV 저장 완료 → {csv_output_path}")

    plt.figure(figsize=(10, 5))
    plt.imshow(wc, interpolation='bilinear')
    plt.axis('off')
    plt.title(f"{language.capitalize()} 리뷰에 대한 워드 클라우드")
    
    output_path = f"../Output/wordcloud_{language}.png"
    wc.to_file(output_path)
    print(f"{language} 워드클라우드 저장 완료 → {output_path}")
    plt.close()

# 6. 전체 흐름 실행 함수
def run_analysis(appid, top_n=20, extra_korean_stopwords=None, extra_english_stopwords=None):
    csv_path = save_reviews_to_csv(appid)
    results = process_reviews_for_keywords(
        csv_file=csv_path,
        top_n=top_n,
        extra_korean_stopwords=extra_korean_stopwords,
        extra_english_stopwords=extra_english_stopwords
    )

    for result in results:
        generate_wordcloud(result['keywords'], result['language'])

# %%
my_korean_stopwords = {'게임', '진짜', '완전'}
my_english_stopwords = {'game', 'really', 'lol'}

run_analysis(appid=2680010, 
             top_n=1000,
             extra_korean_stopwords=my_korean_stopwords,
             extra_english_stopwords=my_english_stopwords)
# Out:
# Saved 200 reviews to ../Output/steam_reviews_2680010.csv
# Extra Korean stopwords: {'완전', '진짜', '게임'}
# Number of words after stopword filtering: 1560
# Extra English stopwords: {'game', 'really', 'lol'}
# Number of words after stopword filtering: 2511
# korean 키워드 빈도 CSV 저장 완료 → ../Output/keyword_freq_korean.csv
# korean 워드클라우드 저장 완료 → ../Output/wordcloud_korean.png
# english 키워드 빈도 CSV 저장 완료 → ../Output/keyword_freq_english.csv
# english 워드클라우드 저장 완료 → ../Output/wordcloud_english.png

# %%
json_data  = fetch_steam_reviews(2680010, language='all', count=100)
json_data
# Out:
# {'success': 1,
#  'query_summary': {'num_reviews': 100,
#   'review_score': 8,
#   'review_score_desc': 'Very Positive',
#   'total_positive': 755,
#   'total_negative': 47,
#   'total_reviews': 802},
#  'reviews': [{'recommendationid': '191098142',
#    'author': {'steamid': '76561198120512205',
#     'num_games_owned': 0,
#     'num_reviews': 32,
#     'playtime_forever': 515,
#     'playtime_last_two_weeks': 515,
#     'playtime_at_review': 260,
#     'last_played': 1742920294},
#    'language': 'english',
#    'review': 'This game is absolutely awesome. I enjoy games like Elden Ring, Dark Souls or Lies of P etc.\n\nIt takes literally all the good parts from those game and take away the annoying parts (like long runbacks etc.).\n\nWhat I really enjoy about it:\n\n- it is not open world. It is kind of "Mission based" starting from a gathering hub.\n- Not a whole lot of trash mobs or traps. Everything is carefully considered (not too much to be annoying, but enough for you to keep attention on the screen)\n- There is always a checkpoint before the Boss of each mission. The runbacks are literally 2 seconds.\n- When you lose a bossfight, you gain ressources based on how low you got the boss (For example, when you died in the first 10 seconds you get 100 souls. If you die after reaching phase 2 and nearly killing the boss, you get like 5000 souls) This way you can still gain levels when trying the boss instead of farming souls from trash. You get rewarded the further you get at the boss. The souls you lose are also always in front  of the boss arena. So you don\'t need to enter to get it.\n- Gameplay is insanely cool. It is similar to Lies of P. Parrying sound is VERY juicy when you hit it right. \n- You gain skill points while fighting (guarding, attacking etc.). So the more you play the game and fight bosses, you increase your player power level. Gain skills and souls.\n- You can ALWAYS change your skill points. There are no drawbacks or ressources needed for it. So if you put points into greatsword and want to switch to dualwield, you can change the skill points to the other weapon\n- Not a lot of weapons (3 types). But the weapon variety comes from each skill tree. VERY GOOD\n- flawless performance. 120 locked FPS at 4k Ultra settings on a 4080 super and 7800x3d\n\nWhat I did not like\n\n- Stamina is very scarce. If you run out of stamina, you get exhausted. The most deaths I had where due to stamina running out. It is annoying at the start. But once you get the hang of it, it gets better. You get stamina when hitting parrys or perfect evades. Some skillpoints also give stamina.\n- Pre-purchare or deluxe armour is kind of very good. It is not cosmetic, it is actual armour with actual stats. At the start it is good to use. But in my opinion not so overpowered that you could say it can carry you. It helps at the start until you get combat down\n- Cinematics sometimes don\'t have audio. I think this is a bug, but they will probably fix it very soon. They are very quick on their feet.\n\nConclusion:\nGREAT Game if you enjoy souls-like Games like Lies of P, but without annoying run-backs and without punishing mechanics like loosing ressources when failing a boss. This game encourages you to get better and rewards you for trying.\n\nI have never experienced a game like this. It feels so good to play. Gameplay feels just perfect.\n\nMy recommendation for anyone who wants to experience some top tier gameplay and want to improve themselve without punishing mechanics.\n',
#    'timestamp_created': 1742846028,
#    'timestamp_updated': 1742846124,
#    'voted_up': True,
#    'votes_up': 209,
#    'votes_funny': 1,
#    'weighted_vote_score': '0.906566023826599121',
#    'comment_count': 4,
#    'steam_purchase': True,
#    'received_for_free': False,
#    'written_during_early_access': False,
#    'primarily_steam_deck': False},
#   {'recommendationid': '191083597',
#    'author': {'steamid': '76561198076353278',
#     'num_games_owned': 478,
#     'num_reviews': 5,
#     'playtime_forever': 111,
#     'playtime_last_two_weeks': 111,
#     'playtime_at_review': 18,
#     'deck_playtime_at_review': 18,
#     'last_played': 1742919187},
#    'language': 'english',
#    'review': "Just a short preview for the game as the early access has now begun, specifically from a PoV of playing on the Steam Deck OLED: \n\n1. Game runs amazingly well with a mix of medium/ low settings at a locked 45FPS (half of the OLED's refresh rate, 90, so it's perfect). It's UE4 so no shitty shader stutters. The Deck's GPU is somewhere around the 1050Ti's performance, so if it can run it at 800p, I think any budget GPU should be able to run it just fine.\n\n2. The weapon feedback is AMAZINGLY well done. So the things like your attacks, your perfect parries and such have a really good and satisfying sound and weight to them, just like Sekiro and Lies of P. It's very similar to Lies of P actually.\n\n3. Game doesn't seem brutally difficult, especially for someone who's played a decent amount of soulslike titles. The parry windows are VERY forgiving, and I think anyone looking for a decent challenge should be able to enjoy the game. I'd rank it somewhere below Wukong in terms of difficulty.\n\n4. I can't say anything about the story or the difficulty in later stages of the game since Ive only played for an hour.\n\n So yeah, I hope this convinces someone who's on the fence right now to get the game or not, especially for their handhelds.",
#    'timestamp_created': 1742834025,
#    'timestamp_updated': 1742834025,
#    'voted_up': True,
#    'votes_up': 98,
#    'votes_funny': 5,
#    'weighted_vote_score': '0.825124204158782959',
#    'comment_count': 7,
#    'steam_purchase': True,
#    'received_for_free': False,
#    'written_during_early_access': False,
#    'primarily_steam_deck': True},
#   {'recommendationid': '191081098',
#    'author': {'steamid': '76561199244584073',
#     'num_games_owned': 0,
#     'num_reviews': 28,
#     'playtime_forever': 1170,
#     'playtime_last_two_weeks': 1170,
#     'playtime_at_review': 30,
#     'last_played': 1742919986},
#    'language': 'koreana',
#    'review': '오다리 사먹는다고 만원빌리고 제주도 네오플로 간 ㅇㄱㅇ 돈갚아라\n\n게임은 무난하게 재밌습니다\n다만 튜토리얼에서 의도적으로 소울식 플레이를 강요하는데\n정작 게임은 진행할수록 액션알피지 쪽이 강해서\n소울식 구평플레이 하면 더럽게 체력만 많고 그로기는 안터지고\n조금만 휘적대면 스테없어서 빌빌대는 노답겜인데\n"카잔스럽게"겜을 하면 확실한 손맛을 보여주고\n아트웍이나 파밍시스템까지 취향에맞으면 재밌게할수있는 무난한겜입니다.\n장수ip이니만큼 dlc나 후속작에 써먹을 소재도 많으니  기대해봅니다.',
#    'timestamp_created': 1742831843,
#    'timestamp_updated': 1742831843,
#    'voted_up': True,
#    'votes_up': 54,
#    'votes_funny': 20,
#    'weighted_vote_score': '0.780710577964782715',
#    'comment_count': 0,
#    'steam_purchase': True,
#    'received_for_free': False,
#    'written_during_early_access': False,
#    'primarily_steam_deck': False},
#   {'recommendationid': '191092704',
#    'author': {'steamid': '76561198076311669',
#     'num_games_owned': 728,
#     'num_reviews': 1,
#     'playtime_forever': 655,
#     'playtime_last_two_weeks': 655,
#     'playtime_at_review': 189,
#     'last_played': 1742919973},
#    'language': 'english',
#    'review': 'Better Berserk than the official Berserk game.\n\nPlays more like a hack & slash than a souls-like after unlocking the skill tree.',
#    'timestamp_created': 1742841296,
#    'timestamp_updated': 1742841296,
#    'voted_up': True,
#    'votes_up': 40,
#    'votes_funny': 3,
#    'weighted_vote_score': '0.763430893421173096',
#    'comment_count': 4,
#    'steam_purchase': True,
#    'received_for_free': False,
#    'written_during_early_access': False,
#    'primarily_steam_deck': False},
#   {'recommendationid': '191095501',
#    'author': {'steamid': '76561198846542626',
#     'num_games_owned': 136,
#     'num_reviews': 11,
#     'playtime_forever': 158,
#     'playtime_last_two_weeks': 158,
#     'playtime_at_review': 90,
#     'last_played': 1742918380},
#    'language': 'russian',
#    'review': 'У местного берсерка из Казани по имени Казан стамины ровно столько, что бы вам разорвали рот от Африки до Антарктиды в бою с количеством мобов, превышающим 1 боевую единицу, ведь если отряд состоит из двух бомжей и одного сильного - вам сделают сладкий ♂️fisting for your ass♂️. И, если вы волнуетесь, что упустите хотя бы одного моба, можете не волноваться, ведь если за вами увязались, то будут бежать прямиком до следующей сюжетной локации. В общем то, очень настойчивые тут противники... А так игру рекомендую, трахают тут знатно. \n\n[quote=Казан] Я терплю и вы терпите. [/quote]',
#    'timestamp_created': 1742843658,
#    'timestamp_updated': 1742843658,
#    'voted_up': True,
#    'votes_up': 44,
#    'votes_funny': 41,
#    'weighted_vote_score': '0.811378240585327148',
#    'comment_count': 0,
#    'steam_purchase': True,
#    'received_for_free': False,
#    'written_during_early_access': False,
#    'primarily_steam_deck': False},
#   {'recommendationid': '191083713',
#    'author': {'steamid': '76561199119051439',
#     'num_games_owned': 2124,
#     'num_reviews': 134,
#     'playtime_forever': 1029,
#     'playtime_last_two_weeks': 1029,
#     'playtime_at_review': 834,
#     'last_played': 1742891061},
#    'language': 'schinese',
#    'review': 'demo升了30多级，技能树点到demo上限了，十里坡剑神归来。打击感不错，大剑点完格挡玩起来有只狼的感觉，处决动画很爽，喜欢黑魂或者仁王这类游戏的玩家必玩。可以先试试demo，本来我打demo第一章也想删游戏，还好坚持了下去，第二章解锁完技能树，游戏才刚刚开始。可以说这款游戏的debuff是叠满的了，国内tx代理，steam高昂定价，dnfip，等等，但这并不妨碍他是一个好的类魂游戏.\n\n正反馈拉满了，跟boss交战，失败了还给魂，而且掉的魂就放门口自动吸回来，真正的越打越强，不仅是你的操作，还有你的数值。\n\n凌晨更新：\n卧槽不是哥们，你这boss人均两形态(打到后面了，其实也没几个两形态的，不知道为啥要把双形态boss放这么前面)，血还巨厚，放其他任何游戏里都是关底boss的水平了，确定血量后面没多打一个0，有点逆天了。不过好在boss动作整体设计的都还不错，说好听点是每个boss都给你其他游戏最终boss的战斗体验，说难听点，能不能把血调低一点，这玩意刮痧半天你告诉我还有二阶段是人打的吗。打个比方就是，打盖尔，有三个阶段，你刮痧半天终于过了，开始放CG了，结果CG放完boss转阶段，还有一管血条，BOSS变成了兽人，而之前的一管血其实还只是第一阶段。BOSS总血条减少一半都很合理，数值设计有大问题，但是跟匹诺曹一样，赶紧趁还没正式发售，改改还有的救，底子是不错的。后面的一些兽形BOSS甚至还有部位破坏机制。\n\n再次更新：\n后面技能点上来后没这些问题了，主要还是加精力伤害为主，多打处决。别像我一样玩巨剑弹半天了，换长枪，随便戳都是硬直，巨剑蓄力重击满加1个能量都没硬直，气笑了。',
#    'timestamp_created': 1742834121,
#    'timestamp_updated': 1742880698,
#    'voted_up': True,
#    'votes_up': 33,
#    'votes_funny': 9,
#    'weighted_vote_score': '0.75151216983795166',
#    'comment_count': 0,
#    'steam_purchase': True,
#    'received_for_free': False,
#    'written_during_early_access': False,
#    'primarily_steam_deck': False},
#   {'recommendationid': '191080342',
#    'author': {'steamid': '76561198097238167',
#     'num_games_owned': 904,
#     'num_reviews': 714,
#     'playtime_forever': 1492,
#     'playtime_last_two_weeks': 1492,
#     'playtime_at_review': 40,
#     'last_played': 1742920324},
#    'language': 'english',
#    'review': "I also tried the demo and was very satisfied with it. It's an action-oriented souls-like game with a rich skill set, an excellent parry timing system, 3 types of weapons (dual wielding/great sword/spear)and a wide variety of enemies. It's fun, needless to say.",
#    'timestamp_created': 1742831143,
#    'timestamp_updated': 1742831591,
#    'voted_up': True,
#    'votes_up': 54,
#    'votes_funny': 3,
#    'weighted_vote_score': '0.705577254295349121',
#    'comment_count': 0,
#    'steam_purchase': True,
#    'received_for_free': False,
#    'written_during_early_access': False,
#    'primarily_steam_deck': False},
#   {'recommendationid': '191130288',
#    'author': {'steamid': '76561198156662717',
#     'num_games_owned': 468,
#     'num_reviews': 5,
#     'playtime_forever': 540,
#     'playtime_last_two_weeks': 540,
#     'playtime_at_review': 310,
#     'last_played': 1742920167},
#    'language': 'russian',
#    'review': 'Крутик, траил ящерицу из начала игры 4 часа, всё ещё болит отверстие чуть ниже спины.\nПока что очень понравилось, что ящерица не просто замахивалась и удерживала атаку как мой отец с ремнём. Но еще и делала крутой спинер над головой, чтоб я визуально понимал, что мне реально дадут леща\nСвага: присутствует',
#    'timestamp_created': 1742883649,
#    'timestamp_updated': 1742883649,
#    'voted_up': True,
#    'votes_up': 22,
#    'votes_funny': 8,
#    'weighted_vote_score': '0.740518689155578613',
#    'comment_count': 0,
#    'steam_purchase': True,
#    'received_for_free': False,
#    'written_during_early_access': False,
#    'primarily_steam_deck': False},
#   {'recommendationid': '191084055',
#    'author': {'steamid': '76561197982995458',
#     'num_games_owned': 805,
#     'num_reviews': 24,
#     'playtime_forever': 377,
#     'playtime_last_two_weeks': 377,
#     'playtime_at_review': 30,
#     'last_played': 1742920993},
#    'language': 'english',
#    'review': "Never liked a demo so much that I preorded the game AND paid extra for early access. I was really smitten with the game right away, it's very fun and very challenging. Also, Playstation Glyphs!!! Using DS4 windows with my Dualshock 4, Steam Input disabled. Game is running great, very well-optimized and streamlined experience.",
#    'timestamp_created': 1742834429,
#    'timestamp_updated': 1742834429,
#    'voted_up': True,
#    'votes_up': 37,
#    'votes_funny': 1,
#    'weighted_vote_score': '0.691092371940612793',
#    'comment_count': 0,
#    'steam_purchase': True,
#    'received_for_free': False,
#    'written_during_early_access': False,
#    'primarily_steam_deck': False},
#   {'recommendationid': '191080610',
#    'author': {'steamid': '76561198253022206',
#     'num_games_owned': 489,
#     'num_reviews': 28,
#     'playtime_forever': 174,
#     'playtime_last_two_weeks': 174,
#     'playtime_at_review': 30,
#     'last_played': 1742853552},
#    'language': 'english',
#    'review': "This is unexpectedly smooth as butter. very fluid game play with a lot of different varieties of play styles and builds that are all viable. I'm Bezerking my Khazan rn",
#    'timestamp_created': 1742831379,
#    'timestamp_updated': 1742831379,
#    'voted_up': True,
#    'votes_up': 37,
#    'votes_funny': 13,
#    'weighted_vote_score': '0.666122138500213623',
#    'comment_count': 0,
#    'steam_purchase': True,
#    'received_for_free': False,
#    'written_during_early_access': False,
#    'primarily_steam_deck': False},
#   {'recommendationid': '191122095',
#    'author': {'steamid': '76561198141996339',
#     'num_games_owned': 5962,
#     'num_reviews': 110,
#     'playtime_forever': 227,
#     'playtime_last_two_weeks': 227,
#     'playtime_at_review': 144,
#     'last_played': 1742915400},
#    'language': 'schinese',
#    'review': '[h3] 玩卡赞的感觉就像我玩了很久魂系列突然开始玩嗜血代码。 [/h3]\n虽然都是差不太多类型的游戏，但是总感觉有一些与众不同。\n\n游戏体整体验挺好的，打击感比预期要好，人物性能也可以，能缝的都缝了，画风我很喜欢，优化也不错。Boss战死了也有魂真的是个好设计，玩了两个小时唯一的槽点就是脱战状态赶路耗体力，跑图有点难受。\n上高中时候开始玩毒奶粉，也是陪伴了我好几年，很怀念当时副本门口摆摊，带别人觉醒，爬塔挣钱的日子。希望未来DNF这个IP能有更好的衍生作品吧。',
#    'timestamp_created': 1742871735,
#    'timestamp_updated': 1742910333,
#    'voted_up': True,
#    'votes_up': 15,
#    'votes_funny': 2,
#    'weighted_vote_score': '0.650782763957977295',
#    'comment_count': 0,
#    'steam_purchase': True,
#    'received_for_free': False,
#    'written_during_early_access': False,
#    'primarily_steam_deck': False},
#   {'recommendationid': '191094988',
#    'author': {'steamid': '76561198116896803',
#     'num_games_owned': 625,
#     'num_reviews': 58,
#     'playtime_forever': 416,
#     'playtime_last_two_weeks': 416,
#     'playtime_at_review': 204,
#     'last_played': 1742920567},
#    'language': 'brazilian',
#    'review': 'Pra você que já jogou Sekiro, Lies of P, parry é essencial nesse jogo principalmente pra sobreviver\nKhazan é um literal action que pega mecânicas de parry (Sekiro), Sumonar aliado (Lies of P) e upar atributos\nVocê também pode dar rematch nas lutas no compendio (muito foda pra memorizar e decorar no NG+)\nOs gráficos estão além do esperado, otimização também atualmente no PC que tenho e por incrível que pareça, o jogo tem uma iluminação e capricho excelentes\n\nEspere uma promoção pra pegar Khazan e lembre-se: toda luta contra bosses e mobs é frenética ala Sekiro\nNunca apresse nada, vá no seu tempo e ...\nTente de novo',
#    'timestamp_created': 1742843218,
#    'timestamp_updated': 1742843218,
#    'voted_up': True,
#    'votes_up': 11,
#    'votes_funny': 1,
#    'weighted_vote_score': '0.643067836761474609',
#    'comment_count': 0,
#    'steam_purchase': True,
#    'received_for_free': False,
#    'written_during_early_access': False,
#    'primarily_steam_deck': False},
#   {'recommendationid': '191081523',
#    'author': {'steamid': '76561198092285101',
#     'num_games_owned': 305,
#     'num_reviews': 50,
#     'playtime_forever': 547,
#     'playtime_last_two_weeks': 547,
#     'playtime_at_review': 354,
#     'last_played': 1742917402},
#    'language': 'english',
#    'review': '5 hour update:\nGame is amazing, the soundtracks for bosses are fire and the mechanics are super tight and feel REALLY good, especially when you can find a really nasty combination of moves to eviscerate enemies. Overall? 9/10\n\n\nGame is good.\nHad me engaged from the moment I played the demo, and have been excited ever since.\nMechanics are solid, gameplay is fun, the story had me hooked and the game runs buttery smooth. (shocker)',
#    'timestamp_created': 1742832204,
#    'timestamp_updated': 1742850829,
#    'voted_up': True,
#    'votes_up': 36,
#    'votes_funny': 2,
#    'weighted_vote_score': '0.640958845615386963',
#    'comment_count': 4,
#    'steam_purchase': True,
#    'received_for_free': False,
#    'written_during_early_access': False,
#    'primarily_steam_deck': False},
#   {'recommendationid': '191089727',
#    'author': {'steamid': '76561198218889663',
#     'num_games_owned': 0,
#     'num_reviews': 36,
#     'playtime_forever': 589,
#     'playtime_last_two_weeks': 589,
#     'playtime_at_review': 151,
#     'last_played': 1742920842},
#    'language': 'schinese',
#    'review': '非常好玩！！！优化也很nice！！！ 长枪推图无双真的很爽感觉是轮椅了\n玩了刺客黑人再玩这个简直如获新生！',
#    'timestamp_created': 1742838917,
#    'timestamp_updated': 1742839084,
#    'voted_up': True,
#    'votes_up': 13,
#    'votes_funny': 9,
#    'weighted_vote_score': '0.621360123157501221',
#    'comment_count': 0,
#    'steam_purchase': True,
#    'received_for_free': False,
#    'written_during_early_access': False,
#    'primarily_steam_deck': False},
#   {'recommendationid': '191092552',
#    'author': {'steamid': '76561198860428448',
#     'num_games_owned': 0,
#     'num_reviews': 88,
#     'playtime_forever': 334,
#     'playtime_last_two_weeks': 334,
#     'playtime_at_review': 148,
#     'last_played': 1742920363},
#    'language': 'koreana',
#    'review': '다크소울 느낌의 필드 구성 + 세키로의 전투맛 살짝 + 나인솔즈의 특수패링 \n약간 병맛같으면서도 전투는 또 재밌네..? 이게 무슨 맛이지 ㅋㅋ\n그래도 기특하다 넥슨!',
#    'timestamp_created': 1742841184,
#    'timestamp_updated': 1742841184,
#    'voted_up': True,
#    'votes_up': 12,
#    'votes_funny': 0,
#    'weighted_vote_score': '0.596565604209899902',
#    'comment_count': 1,
#    'steam_purchase': True,
#    'received_for_free': False,
#    'written_during_early_access': False,
#    'primarily_steam_deck': False},
#   {'recommendationid': '191139625',
#    'author': {'steamid': '76561198161769160',
#     'num_games_owned': 0,
#     'num_reviews': 15,
#     'playtime_forever': 344,
#     'playtime_last_two_weeks': 344,
#     'playtime_at_review': 295,
#     'last_played': 1742901937},
#    'language': 'schinese',
#    'review': '仁王韩国版，该抄的抄了，不该抄的地图设计和瞎眼光影也抄了，近期唯一主动性高的arpg，好玩没代餐，可以买，但不值这个价。',
#    'timestamp_created': 1742898464,
#    'timestamp_updated': 1742898464,
#    'voted_up': False,
#    'votes_up': 21,
#    'votes_funny': 0,
#    'weighted_vote_score': '0.606792330741882324',
#    'comment_count': 0,
#    'steam_purchase': True,
#    'received_for_free': False,
#    'written_during_early_access': False,
#    'primarily_steam_deck': False},
#   {'recommendationid': '191143289',
#    'author': {'steamid': '76561198149966648',
#     'num_games_owned': 0,
#     'num_reviews': 33,
#     'playtime_forever': 286,
#     'playtime_last_two_weeks': 286,
#     'playtime_at_review': 181,
#     'last_played': 1742909234},
#    'language': 'schinese',
#    'review': 'boss除了又臭又长的连击，快慢刀，神经刀和零帧起手还有其他风格吗？打吐了，就是不断死，不断适应快慢刀，熟悉boss节奏，强推自以为是的动作系统。找不出一点能打立回，压制的途径。别拿demo刷级三十级起点来搪塞人，正常玩家，走到幽魂那里，能三十级？这游戏缝了魂的精力，仁王的派生，只狼的弹刀，以为自己的动作系统无敌。却不知道，只狼弹刀的灵活性被精力限制，仁王削精连段压制因为无回精手段被限制，糟糕且机械的boss设计，毫无交互，只抄类魂的表面，仁王的垃圾boss设计好歹给99武器和妖怪技反制，这里全换成弹刀，收益还没有只狼大。别的游戏各种里技，这里我只搓出个，长枪强袭重踢+处决，boss回满精，我空精的局面。各作的精髓中取表面，然后再把糟粕拿过来去掉最屎的部分，糅合起来的四不像。我都分不清是屎是糖了。给点回精手段吧，我都分不清我打的是压制还是立回了，boss逻辑也是愣死了，强行和玩家一个屎样，打一整套，快空精了就绕圈圈。好好打磨吧，我愿称它为屎味的巧克力，能吃吗，能吃，也是真的恶心。各系统根本没成一个整体，来点自己的设计与思考好吧。boss设计和交互做不到宫崎英高那样就别整这个精力条了。连段优秀，没法连爽，寸止挑战吗？回精手段和红狗标志的血气资源快点加上啊！',
#    'timestamp_created': 1742903442,
#    'timestamp_updated': 1742903442,
#    'voted_up': True,
#    'votes_up': 9,
#    'votes_funny': 0,
#    'weighted_vote_score': '0.620453834533691406',
#    'comment_count': 0,
#    'steam_purchase': True,
#    'received_for_free': False,
#    'written_during_early_access': False,
#    'primarily_steam_deck': False},
#   {'recommendationid': '191142850',
#    'author': {'steamid': '76561199252041963',
#     'num_games_owned': 0,
#     'num_reviews': 1,
#     'playtime_forever': 711,
#     'playtime_last_two_weeks': 711,
#     'playtime_at_review': 498,
#     'last_played': 1742920778},
#    'language': 'schinese',
#    'review': '制作组越是低能就越是喜欢在主推精闪精防的游戏里限制角色性能、塞神经刀粪怪，就尼玛这点精力条让人吃屎啊？私募棒子真尼玛废物，仁王精力管理没本事学就学魂的垃圾精力条，私募棒子把他亲爹郎格斯做进了游戏，割了全体制作组人员的腰子给他爹狠狠补，精力充沛回得比掉的还快，可惜还是被我宰了，500的赤石费就当你爹的棺材本吧，不用退了',
#    'timestamp_created': 1742902869,
#    'timestamp_updated': 1742902869,
#    'voted_up': False,
#    'votes_up': 7,
#    'votes_funny': 0,
#    'weighted_vote_score': '0.59356766939163208',
#    'comment_count': 0,
#    'steam_purchase': True,
#    'received_for_free': False,
#    'written_during_early_access': False,
#    'primarily_steam_deck': False},
#   {'recommendationid': '191108086',
#    'author': {'steamid': '76561198065502044',
#     'num_games_owned': 538,
#     'num_reviews': 35,
#     'playtime_forever': 5,
#     'playtime_last_two_weeks': 5,
#     'playtime_at_review': 5,
#     'last_played': 1742855375},
#    'language': 'koreana',
#    'review': '게임에 딱히 관심없고 구매시 주는 던파 특전 아이템 받으려고 샀는데\n\n아이템 언제 줌',
#    'timestamp_created': 1742855472,
#    'timestamp_updated': 1742855625,
#    'voted_up': True,
#    'votes_up': 17,
#    'votes_funny': 5,
#    'weighted_vote_score': '0.591882050037384033',
#    'comment_count': 14,
#    'steam_purchase': True,
#    'received_for_free': False,
#    'written_during_early_access': False,
#    'primarily_steam_deck': False},
#   {'recommendationid': '191133322',
#    'author': {'steamid': '76561198050856849',
#     'num_games_owned': 0,
#     'num_reviews': 4,
#     'playtime_forever': 634,
#     'playtime_last_two_weeks': 634,
#     'playtime_at_review': 557,
#     'last_played': 1742907731},
#    'language': 'japanese',
#    'review': '仁王系統のハクスラ要素あり死にゲーです、悪名高いネクソンですが細かいところまでしっかり作られた正統派な良ソウルライクゲーの手ごたえを感じます。\n\n戦闘面は効果音・モーション・エフェクトのお蔭で戦ってて気持ちよく、序盤から殺意マックスのボス戦はひたすらに楽しいです。\n\nジャスト回避・ガードのリターンがとても大きく設定されていてスキルの成長に従ってより顕著になっていきます\nジャスガには複数の亜種のようなものがあり判定が難しい反面ボス級の相手にも通用し決まればしばらくの間一方的に殴れるのが気持ちよすぎます。\n\n装備品はレア度設定がコモン・アンコモン・レア・ユニーク・エピック・レジェンダリーと幅広くレア度にかかわらずセット品も存在しハクスラ欲を満たすには申し分ない作りだと思います(オプションは勿論RNG有)\n\n体験版から少し先に進んだ時点での感想です、参考になれば幸いです。',
#    'timestamp_created': 1742888773,
#    'timestamp_updated': 1742904785,
#    'voted_up': True,
#    'votes_up': 6,
#    'votes_funny': 0,
#    'weighted_vote_score': '0.587837815284729004',
#    'comment_count': 0,
#    'steam_purchase': True,
#    'received_for_free': False,
#    'written_during_early_access': False,
#    'primarily_steam_deck': False},
#   {'recommendationid': '191106248',
#    'author': {'steamid': '76561198368704777',
#     'num_games_owned': 158,
#     'num_reviews': 12,
#     'playtime_forever': 374,
#     'playtime_last_two_weeks': 374,
#     'playtime_at_review': 40,
#     'last_played': 1742919620},
#    'language': 'russian',
#    'review': 'Еще с бетки осознал что будет качественная рубка врагов, на релизе точно это же и получил\nОптимизация хорошая, рубить врагов одно удовольствие, графика глазу приятная\nПофиксили пару кривых анимаций, первое впечатление крайне положительное, денег своих стоит\nP.S Для тех кто в таких играх не опытный, разработчик добавил более легкую сложность, отдельный респект для начинающих плееров',
#    'timestamp_created': 1742853623,
#    'timestamp_updated': 1742853727,
#    'voted_up': True,
#    'votes_up': 5,
#    'votes_funny': 0,
#    'weighted_vote_score': '0.580419540405273438',
#    'comment_count': 0,
#    'steam_purchase': True,
#    'received_for_free': False,
#    'written_during_early_access': False,
#    'primarily_steam_deck': False},
#   {'recommendationid': '191123177',
#    'author': {'steamid': '76561198211781880',
#     'num_games_owned': 75,
#     'num_reviews': 13,
#     'playtime_forever': 439,
#     'playtime_last_two_weeks': 439,
#     'playtime_at_review': 156,
#     'last_played': 1742914657},
#    'language': 'schinese',
#    'review': '地图一坨，怪物数值一坨，堆怪一坨，主角受击一坨，价格一坨，不打骨折都不建议入，真想玩就拿着这四百块去买打折的老头环和只狼',
#    'timestamp_created': 1742873075,
#    'timestamp_updated': 1742873075,
#    'voted_up': False,
#    'votes_up': 25,
#    'votes_funny': 5,
#    'weighted_vote_score': '0.587772905826568604',
#    'comment_count': 0,
#    'steam_purchase': True,
#    'received_for_free': False,
#    'written_during_early_access': False,
#    'primarily_steam_deck': False,
#    'timestamp_dev_responded': 1742901971,
#    'developer_response': '您好，我们是《The First Berserker: Khazan》开发团队。\n很抱歉为您带来了不好的游戏体验。\n我们会认真对待每一位玩家的反馈，并持续努力，力求打造更好的游戏内容。\n衷心感谢您宝贵的意见与关注。'},
#   {'recommendationid': '191100143',
#    'author': {'steamid': '76561198079740099',
#     'num_games_owned': 596,
#     'num_reviews': 17,
#     'playtime_forever': 450,
#     'playtime_last_two_weeks': 450,
#     'playtime_at_review': 218,
#     'last_played': 1742902415},
#    'language': 'brazilian',
#    'review': "Esse jogo é sensacional, não diria que ele é um soulslike tradicional como os Dark Souls, pode ser que enquadrar ele de uma forma mais amigável seja a melhor definição.\n\nA atmosfera do jogo é linda, o combate é prazeroso e é realmente legal o sisteminha de parry que tem.\n\nMuito bom pra quem sabe dividir as coisas entre um bom soulslike e um hack'n'slash.",
#    'timestamp_created': 1742847805,
#    'timestamp_updated': 1742847805,
#    'voted_up': True,
#    'votes_up': 4,
#    'votes_funny': 0,
#    'weighted_vote_score': '0.565217375755310059',
#    'comment_count': 0,
#    'steam_purchase': True,
#    'received_for_free': False,
#    'written_during_early_access': False,
#    'primarily_steam_deck': False},
#   {'recommendationid': '191128774',
#    'author': {'steamid': '76561197999983175',
#     'num_games_owned': 609,
#     'num_reviews': 128,
#     'playtime_forever': 389,
#     'playtime_last_two_weeks': 389,
#     'playtime_at_review': 389,
#     'last_played': 1742878721},
#    'language': 'english',
#    'review': 'How to describe this game..\n\nIt\'s pretty good. I can say that much. Viper is gonna be a huge Filter, I eased through the game until him and he gave me a true ass kicking.\n\nI\'ll just point out some things and what i\'ve experienced vs my thoughts.\n\n[h1]1. Level Design. [/h1]\nIt\'s mission based, So you aren\'t really lost per se, of course its up to you to explore the levels and find all the things. A game you can compare this to would be Nioh. To be honest I kind of like it like this a lot more. Too many games are trying to be Open World without making it feel worth it.\n\n[h1]2. Consumables and Aid[/h1]\n Items to upgrade your healing capacity seem to be pretty far and few between? I think im about past halfway through chapter 4 and I\'ve only found a single upgrade, giving me a healing capacity of 4 totals heals, which isn\'t a lot. it seems each one of the heals gives you around 50% ish hp which adversely is quite a lot, which can be upgraded further with healing recieved stat on gear and items.\n\nI\'m not sure if using these consumables are really worth the time to pop them and the cost to restock them. Continuing to wait for the day a souls-game releases where consumables are refreshed at checkpoints.\n\n[h1]3. Gear upgrading[/h1]\nLevelled and RNG gear. a Classic of RPGs, you can get gear that is either godly or Scheiße. I dont even see what the point of the non-set gear is personally, the stat upgrades from set bonuses seem way too good to pass over.\n\n[h1]4. Low weapon variety.[/h1]\nBasically, you only have Dual Wield (Which is depicted as a sword and axe), Spear and Greatsword weapon options. To be honest they all are pretty good and have their own certain niches to fulfill with fighting. I was stuck on Viper for a while while using the spear, but when I played more defensively with a greatsword, I overcame him after a few more attempts!\n\n[h1]5. Levelling.[/h1]\nI\'m not entirely too sure if investing in stats other than HP and Stamina is overly worth it, to be honest, the damage numbers are really low, each point of STR adds like 3 damage to a greatsword, which each swing already does like 300-400, but one point of HP adds 50 health? Seems to be a way bigger return on the investment, i think? I\'ve yet to reach a softcap or a diminishing return at 22 HP stat.\n\n[h1]5. Skills.[/h1]\nAside from genuine playerskill, there is the alternative levelling, which is gaining skillpoints by just playing the game. This is similar to Nioh where you would play with a specific weapon and earn skill points in that category, however in this game, the skillpoints are universal, and there is also a "Common" skill tree which affects you universally. In particular within this tree is the "Reflection" skill.\n\n"Reflection" acts as another type of parry, but it\'s honestly more of an offensive type of parry, It\'s timing window is extremely strict, far more stricter than standard parrying, which is called a "Brink Block", but by god is the pay off worth it for skillful use of it. If you can [b]Master Reflection[/b], you will have [b]beaten[/b] this game. \n\nAnother great thing is that you can freely redistribute used Skill points into other skills for free. So you can flow between weapons that you are currently using, or adapt your current playstyle.\n\n[h1]6. Visuals and Audio.[/h1]\nGame looks stunning, the graphics contain just the right amount of effects, colour, and the audio is great too. It\'s also done in anime style, so it\'s easy on the eyes too.\n\n[h1]7. Animations.[/h1]\nThe animations are overall pretty good too, though there are sometimes where you will go "???" as you get hit by something, or certain enemy attacks are just.. wild.. to look at.\n\n[h1]8. Combat Balance.[/h1]\nThe game feels well balanced in a lot of respects, The minions are weak, and die quickly, but will give you a run for your money in a group, just as it should be. bigger and elite enemies will kick your ass a bit, until yo ...
#    'timestamp_created': 1742881084,
#    'timestamp_updated': 1742881510,
#    'voted_up': True,
#    'votes_up': 3,
#    'votes_funny': 0,
#    'weighted_vote_score': '0.562289595603942871',
#    'comment_count': 0,
#    'steam_purchase': True,
#    'received_for_free': False,
#    'written_during_early_access': False,
#    'primarily_steam_deck': False},
#   {'recommendationid': '191145691',
#    'author': {'steamid': '76561199004362263',
#     'num_games_owned': 13,
#     'num_reviews': 3,
#     'playtime_forever': 781,
#     'playtime_last_two_weeks': 781,
#     'playtime_at_review': 666,
#     'last_played': 1742913235},
#    'language': 'schinese',
#    'review': '太好了是nexon的屎我们死定了！好好好人设改得连亲妈都不认识了，你说面向dnf玩家吧它剧情写了依托，你说给全球玩家做吧，你不玩dnf还看不懂伏笔。美术音乐没问题，剧情一坨大的给我看傻了，打着复仇的旗号其实最后复仇了个寂寞，一点时代背景都不介绍，人物塑造是没有的，情感共鸣是不存在的，杀完这个杀那个，好，我卡赞就是冒险家转世，你让我杀谁我杀谁。468我买了一坨没精力的还没有膝盖跳不起来的残废，问就是流放后遗症，太棒了玩dnf的心终于死透了！哈哈',
#    'timestamp_created': 1742906280,
#    'timestamp_updated': 1742906280,
#    'voted_up': False,
#    'votes_up': 5,
#    'votes_funny': 1,
#    'weighted_vote_score': '0.561034739017486572',
#    'comment_count': 0,
#    'steam_purchase': True,
#    'received_for_free': False,
#    'written_during_early_access': False,
#    'primarily_steam_deck': False},
#   {'recommendationid': '191109156',
#    'author': {'steamid': '76561199207409973',
#     'num_games_owned': 0,
#     'num_reviews': 12,
#     'playtime_forever': 841,
#     'playtime_last_two_weeks': 841,
#     'playtime_at_review': 438,
#     'deck_playtime_at_review': 438,
#     'last_played': 1742918031},
#    'language': 'english',
#    'review': 'The combat isn’t boring, and while the graphics aren’t mind-blowing, the overall experience is really fun. The main character and NPCs look great, and the environment design is top-notch.\n\nIt’s cool to see a Souls like game with a difficulty setting!\n\nI’d say it totally deserves a 9 out of 10.\n\n',
#    'timestamp_created': 1742856607,
#    'timestamp_updated': 1742856607,
#    'voted_up': True,
#    'votes_up': 4,
#    'votes_funny': 1,
#    'weighted_vote_score': '0.560439586639404297',
#    'comment_count': 0,
#    'steam_purchase': True,
#    'received_for_free': False,
#    'written_during_early_access': False,
#    'primarily_steam_deck': True},
#   {'recommendationid': '191140807',
#    'author': {'steamid': '76561199442401250',
#     'num_games_owned': 50,
#     'num_reviews': 2,
#     'playtime_forever': 354,
#     'playtime_last_two_weeks': 354,
#     'playtime_at_review': 158,
#     'last_played': 1742910323},
#    'language': 'english',
#    'review': "it's like dark souls but you play with a anime characters 10/10 would recommend",
#    'timestamp_created': 1742900130,
#    'timestamp_updated': 1742900130,
#    'voted_up': True,
#    'votes_up': 4,
#    'votes_funny': 0,
#    'weighted_vote_score': '0.559050261974334717',
#    'comment_count': 0,
#    'steam_purchase': True,
#    'received_for_free': False,
#    'written_during_early_access': False,
#    'primarily_steam_deck': False},
#   {'recommendationid': '191112385',
#    'author': {'steamid': '76561199074752314',
#     'num_games_owned': 0,
#     'num_reviews': 57,
#     'playtime_forever': 408,
#     'playtime_last_two_weeks': 408,
#     'playtime_at_review': 287,
#     'last_played': 1742919829},
#    'language': 'koreana',
#    'review': '준수한 최적화,깔끔한 그래픽,시원한 타격감,원작을 잘 몰라도 이해가능한 주인공의 서사 등등...\n모든 면에서 만족할 만큼 잘 나온 것 같습니다\n\n가장 만족스러웠던 점은\n소울라이크 특성상 쓸데없는 난해한 스토리를 배제하고 액션과 전투에 집중한 점이 정말 좋았습니다\n조작법도 단순한 점이 전투에 몰입할 수 있게 해줬으며,난이도 또한 아주 높게 설정하지 않아 적절히 도전욕구를 자극하게 만들었습니다\n소울라이크 게임이지만 누구든 도전 할 수 있게끔 대중성을 잘 고려해서 만든 것 같습니다\n\n개인적으로 추천 할 만한 게임이지만 소울라이크 게임이 어려워 꺼려지거나 이번에 도전해 보려하는 분들은\n환불 가능 2시간내에 플레이 해보고 결정하는 것도 나쁘지 않다고 생각합니다\n충분히 그 시간내에 결정 할 수 있을 만큼 초반 내용도 알차다고 생각합니다',
#    'timestamp_created': 1742859990,
#    'timestamp_updated': 1742860358,
#    'voted_up': True,
#    'votes_up': 6,
#    'votes_funny': 0,
#    'weighted_vote_score': '0.550898194313049316',
#    'comment_count': 0,
#    'steam_purchase': True,
#    'received_for_free': False,
#    'written_during_early_access': False,
#    'primarily_steam_deck': False},
#   {'recommendationid': '191115740',
#    'author': {'steamid': '76561199804521362',
#     'num_games_owned': 0,
#     'num_reviews': 2,
#     'playtime_forever': 17,
#     'playtime_last_two_weeks': 17,
#     'playtime_at_review': 17,
#     'last_played': 1742862759},
#    'language': 'english',
#    'review': 'Amazing...Just amazing combat. Best game since the original God of war',
#    'timestamp_created': 1742864007,
#    'timestamp_updated': 1742864007,
#    'voted_up': True,
#    'votes_up': 4,
#    'votes_funny': 0,
#    'weighted_vote_score': '0.54954075813293457',
#    'comment_count': 0,
#    'steam_purchase': True,
#    'received_for_free': False,
#    'written_during_early_access': False,
#    'primarily_steam_deck': False},
#   {'recommendationid': '191142355',
#    'author': {'steamid': '76561198004096811',
#     'num_games_owned': 6826,
#     'num_reviews': 92,
#     'playtime_forever': 257,
#     'playtime_last_two_weeks': 257,
#     'playtime_at_review': 257,
#     'last_played': 1742901756},
#    'language': 'english',
#    'review': 'Kinda reminds me of Nioh. Not as responsive though, I dig the art style a lot. I think its dumb you cat several weapon types but can only equip one. Stat system is lacking compared to other games in the genre. Missing (at least from what i can tell) would be a transmog system. \n\nStill a fun game. Worth the price I paid.',
#    'timestamp_created': 1742902249,
#    'timestamp_updated': 1742902249,
#    'voted_up': True,
#    'votes_up': 2,
#    'votes_funny': 0,
#    'weighted_vote_score': '0.547671854496002197',
#    'comment_count': 0,
#    'steam_purchase': True,
#    'received_for_free': False,
#    'written_during_early_access': False,
#    'primarily_steam_deck': False},
#   {'recommendationid': '191133999',
#    'author': {'steamid': '76561197963339561',
#     'num_games_owned': 0,
#     'num_reviews': 28,
#     'playtime_forever': 254,
#     'playtime_last_two_weeks': 254,
#     'playtime_at_review': 141,
#     'last_played': 1742902733},
#    'language': 'english',
#    'review': 'As a 50+ year old father with diminishing hand-eye coordination and limited playing time...thank you so much for easy mode. Fun game!',
#    'timestamp_created': 1742889844,
#    'timestamp_updated': 1742889844,
#    'voted_up': True,
#    'votes_up': 4,
#    'votes_funny': 0,
#    'weighted_vote_score': '0.5465240478515625',
#    'comment_count': 0,
#    'steam_purchase': True,
#    'received_for_free': False,
#    'written_during_early_access': False,
#    'primarily_steam_deck': False},
#   {'recommendationid': '191107131',
#    'author': {'steamid': '76561199111454806',
#     'num_games_owned': 37,
#     'num_reviews': 18,
#     'playtime_forever': 1328,
#     'playtime_last_two_weeks': 1328,
#     'playtime_at_review': 393,
#     'last_played': 1742920844},
#    'language': 'schinese',
#    'review': '这个价格目前来看不值400大洋 仁王完全是它的上位替代 而且里面有个图感觉就是仁王2打斋藤义龙的那关和仁王1打蜘蛛那关的结合体 韩国游戏一贯的老毛病给怪疯狂加神经刀然后鼓励你去弹反（说的就是你匹诺曹）武器强度严重失衡而且只有三种类型的武器（目前来看是这样的不知道后面有没有但我觉得不太可能）这款游戏只能说是dnf的粉丝向作品了',
#    'timestamp_created': 1742854517,
#    'timestamp_updated': 1742854517,
#    'voted_up': False,
#    'votes_up': 12,
#    'votes_funny': 1,
#    'weighted_vote_score': '0.546238601207733154',
#    'comment_count': 0,
#    'steam_purchase': True,
#    'received_for_free': False,
#    'written_during_early_access': False,
#    'primarily_steam_deck': False,
#    'timestamp_dev_responded': 1742903114,
#    'developer_response': '亲爱的玩家，您好！\n非常感谢您给予我们坦率而具体的评价。\n\n我个人也非常喜欢《仁王（Nioh）》这款游戏，我们在开发过程中确实也从《仁王》的设计中获得了不少灵感。\n我们一直坚持“怪物的攻击必须是可读且可应对的”这一核心原则，\n但这方面可能确实还有不少不足。\n\n如果您方便的话，能否告诉我们您觉得问题最严重的怪物或攻击类型是什么？\n如果您愿意分享，我们会积极在团队内部进行讨论，尽力进行改进和优化。\n\n关于武器部分，我们虽然在种类上有所取舍，但我们的目标是让每种武器都具备如同一个角色般的深度与玩法。\n游戏中支持多种Build组合方式，我们也希望玩家可以通过技能、套装效果等构建出自己喜欢的战斗风格。\n如果您在这方面也有希望改进的地方，非常欢迎您继续提出建议！\n\n本次《卡赞》虽然基于DNF的世界观展开，但我们更希望能为喜爱动作游戏的玩家们带来全新的体验与乐趣。\n我们将通过后续更新，持续推出更多内容并优化游戏平衡性。\n\n再次感谢您宝贵的意见与支持！'},
#   {'recommendationid': '191143749',
#    'author': {'steamid': '76561198086250205',
#     'num_games_owned': 223,
#     'num_reviews': 9,
#     'playtime_forever': 296,
#     'playtime_last_two_weeks': 296,
#     'playtime_at_review': 126,
#     'last_played': 1742919393},
#    'language': 'english',
#    'review': 'So far the game is amazing. loved the demo so I got the game, and it’s not a disappointment. I love the parrying the combat system and weapons. Definitely recommend this game',
#    'timestamp_created': 1742904020,
#    'timestamp_updated': 1742904020,
#    'voted_up': True,
#    'votes_up': 2,
#    'votes_funny': 0,
#    'weighted_vote_score': '0.545454561710357666',
#    'comment_count': 0,
#    'steam_purchase': True,
#    'received_for_free': False,
#    'written_during_early_access': False,
#    'primarily_steam_deck': False},
#   {'recommendationid': '191127221',
#    'author': {'steamid': '76561198894697631',
#     'num_games_owned': 44,
#     'num_reviews': 2,
#     'playtime_forever': 231,
#     'playtime_last_two_weeks': 231,
#     'playtime_at_review': 199,
#     'last_played': 1742882328},
#    'language': 'schinese',
#    'review': '动作设计和打击感非常好的类魂了，bbq立项之初应该就是奔着动作网游去做的，三渲二的画风还挺好的优化好做也契合dnf的背景，最大的缺点应该只是贵了，非常希望见到更多dnf universe的作品，支持了',
#    'timestamp_created': 1742878674,
#    'timestamp_updated': 1742878674,
#    'voted_up': True,
#    'votes_up': 3,
#    'votes_funny': 0,
#    'weighted_vote_score': '0.565217375755310059',
#    'comment_count': 0,
#    'steam_purchase': True,
#    'received_for_free': False,
#    'written_during_early_access': False,
#    'primarily_steam_deck': False},
#   {'recommendationid': '191094996',
#    'author': {'steamid': '76561198043953247',
#     'num_games_owned': 181,
#     'num_reviews': 5,
#     'playtime_forever': 1054,
#     'playtime_last_two_weeks': 1054,
#     'playtime_at_review': 134,
#     'last_played': 1742915286},
#    'language': 'russian',
#    'review': 'Отличная рисовка мира, шикарный геймплей, наверно интересный лор, в данный момент он затягивает лично меня, есть интрига. Боссы шикарные, особенно призрак клинка.\nОтличная игра и считаю стоит своих денег до каждой копеечки!\n',
#    'timestamp_created': 1742843228,
#    'timestamp_updated': 1742843228,
#    'voted_up': True,
#    'votes_up': 2,
#    'votes_funny': 0,
#    'weighted_vote_score': '0.54356849193572998',
#    'comment_count': 0,
#    'steam_purchase': True,
#    'received_for_free': False,
#    'written_during_early_access': False,
#    'primarily_steam_deck': False},
#   {'recommendationid': '191134290',
#    'author': {'steamid': '76561198069754051',
#     'num_games_owned': 0,
#     'num_reviews': 2,
#     'playtime_forever': 665,
#     'playtime_last_two_weeks': 665,
#     'playtime_at_review': 217,
#     'last_played': 1742917287},
#    'language': 'koreana',
#    'review': '넥슨에서 이런 게임을 만들었다니 믿어지지 않는군요.\r\n이전 국산 소울인 피구라 보다 더 쫀쫀하고 잼있네요. 강추합니다.',
#    'timestamp_created': 1742890291,
#    'timestamp_updated': 1742890291,
#    'voted_up': True,
#    'votes_up': 5,
#    'votes_funny': 0,
#    'weighted_vote_score': '0.542436718940734863',
#    'comment_count': 0,
#    'steam_purchase': True,
#    'received_for_free': False,
#    'written_during_early_access': False,
#    'primarily_steam_deck': False},
#   {'recommendationid': '191115752',
#    'author': {'steamid': '76561198026576549',
#     'num_games_owned': 107,
#     'num_reviews': 20,
#     'playtime_forever': 505,
#     'playtime_last_two_weeks': 505,
#     'playtime_at_review': 220,
#     'last_played': 1742888845},
#    'language': 'english',
#    'review': "Game feels really good to play, attacks and parries feel weighty, bosses seem very well designed, and it's the most realistic anime art style that I've seen in a game - it looks really good.",
#    'timestamp_created': 1742864024,
#    'timestamp_updated': 1742864024,
#    'voted_up': True,
#    'votes_up': 2,
#    'votes_funny': 0,
#    'weighted_vote_score': '0.541984736919403076',
#    'comment_count': 0,
#    'steam_purchase': True,
#    'received_for_free': False,
#    'written_during_early_access': False,
#    'primarily_steam_deck': False},
#   {'recommendationid': '191133695',
#    'author': {'steamid': '76561198060843893',
#     'num_games_owned': 112,
#     'num_reviews': 14,
#     'playtime_forever': 756,
#     'playtime_last_two_weeks': 756,
#     'playtime_at_review': 273,
#     'last_played': 1742919616},
#    'language': 'russian',
#    'review': 'Не слушайте пока дypa4кoв, они за 1.5 ч игры вам ничего о игре не скажут - есть демка, сами сыграйте).\n Пока напоминает нью ген соулс лайк игры. Почему нью ген? Механник тьма, и каждый настраивает свой тип геймплея. По скорости напоминает секиро, по сеттингу code vein на максималках, а по эпичности тот самый старый God of war. Прокачка и вариативность способностей как в старой доброй DMC. в общем годно и сочно, пока. Но духота чувствуется, веет.',
#    'timestamp_created': 1742889402,
#    'timestamp_updated': 1742889647,
#    'voted_up': True,
#    'votes_up': 3,
#    'votes_funny': 0,
#    'weighted_vote_score': '0.53963083028793335',
#    'comment_count': 0,
#    'steam_purchase': True,
#    'received_for_free': False,
#    'written_during_early_access': False,
#    'primarily_steam_deck': False},
#   {'recommendationid': '191141474',
#    'author': {'steamid': '76561198218023557',
#     'num_games_owned': 0,
#     'num_reviews': 84,
#     'playtime_forever': 211,
#     'playtime_last_two_weeks': 211,
#     'playtime_at_review': 211,
#     'last_played': 1742900551},
#    'language': 'schinese',
#    'review': '首先地图反馈太少，几乎是没有什么探索欲望，反而像是在给人一种想体验爽快的对战首先得先过了无聊的地图的感觉。不可否认的优点是在于人物动作模版流畅且boss战互动交感很好，但是出色的角色动作在小怪上却根本发挥不出来，地图又无探索欲望导致给我的感觉就很无聊只能强撑着去打boss才行，地图多无意义的陷阱，消耗性回血就像是在弥补血瓶很少的缺点虽然总体是够的但是打boss还是显得血瓶不够用可能本意是打boss的时候用消耗性回血道具，但是我玩游戏一般不太喜欢用消耗道具导致回血体验不佳。再就是最重要的问题定价太贵游戏内容过少，游戏只有三种武器新鲜感不足，其他消耗性道具也没有捡的必要，召唤帮手又需要道具比较繁琐总而言之只有boss方面的体验感很好。建议打折入手',
#    'timestamp_created': 1742901084,
#    'timestamp_updated': 1742901084,
#    'voted_up': False,
#    'votes_up': 3,
#    'votes_funny': 1,
#    'weighted_vote_score': '0.5378151535987854',
#    'comment_count': 0,
#    'steam_purchase': True,
#    'received_for_free': False,
#    'written_during_early_access': False,
#    'primarily_steam_deck': False},
#   {'recommendationid': '191086686',
#    'author': {'steamid': '76561198430323549',
#     'num_games_owned': 0,
#     'num_reviews': 15,
#     'playtime_forever': 649,
#     'playtime_last_two_weeks': 649,
#     'playtime_at_review': 121,
#     'last_played': 1742919750},
#    'language': 'koreana',
#    'review': '보스 모션이 어색한점이 많고 필드가 진짜 어지러움. 퍼즐이라고 넣어둔 장치는 직관적이지 않고 퍼즐간의 연결성도 잘 모르걨음 심지어 화톳불까지 거리가 진짜 개 시1발에 함정은 지랄나게 많고 몬스터 딜은 푹찍마냥 한방에 반피 이상을 까는 공격이 많음 나중에는 뒤에서 창만던지고있는 내 모습을 볼수있음. 내가 퍼스트 버서커:카잔을 샀는지 아니면 니달리 시뮬레이터를 샀는지 구별이 안감',
#    'timestamp_created': 1742836609,
#    'timestamp_updated': 1742836609,
#    'voted_up': False,
#    'votes_up': 28,
#    'votes_funny': 9,
#    'weighted_vote_score': '0.534573197364807129',
#    'comment_count': 0,
#    'steam_purchase': True,
#    'received_for_free': False,
#    'written_during_early_access': False,
#    'primarily_steam_deck': False,
#    'timestamp_dev_responded': 1742903089,
#    'developer_response': '안녕하세요. 카잔 개발팀의 이준호입니다. 진솔한 플레이 경험과 피드백 감사드려요. 보스 모션의 어색함, 필드 구성의 혼란함, 퍼즐의 직관성 부족등 말씀해주신 부분들 모두 진지하게 검토해보겠습니다. 몬스터의 딜이 높은 부분에 대해 - 괜찮으시다면 가드를 활용해보시면 좋을거 같아요. 저희는 가드의 성능을 상당히 높게 만들어 놨습니다. 막으면 기력을 사용하는 대신 확실히 체력 피해를 줄여줘요! 가드 기력 피해를 줄이는 스킬을 찍으시면 더 도움이 됩니다. 만약 적이 공격하는 타이밍에 익숙해지셨다면 - 타이밍에 맞춰서 가드키를 눌러 - 직전 가드를 해보셔요. 직전가드는 저의 기력 피해는 줄이고, 적에게 피해도 입히구요. 여기서 파생되는 스킬들도 효율적인 것들이 많습니다. 이렇게 적의 공격에 피해를 줄이고 기력을 모아서 기회가 될때 공격하는 방식으로 해보시면 좋을거 같아요. 부디 이 작은 팁이 도움이 되셨길 바라구요. 게임의 전반적인 흐름이나 전투 스타일이 기대와 어긋난 점에 대해 깊이 공감하고, 그럼에도 불구하고 소중한 의견을 남겨주셔서 고맙습니다. 더 나은 게임을 만들기 위해 계속 노력하겠습니다. '},
#   {'recommendationid': '191105044',
#    'author': {'steamid': '76561198091387793',
#     'num_games_owned': 2015,
#     'num_reviews': 31,
#     'playtime_forever': 324,
#     'playtime_last_two_weeks': 324,
#     'playtime_at_review': 227,
#     'last_played': 1742863897},
#    'language': 'english',
#    'review': 'Balancing issues. They say it get easier but omg is it impossible. I know ill be trolled but I beat Elden Ring Expansion and I never had this much difficulty. The first boss is impossibly challenging.',
#    'timestamp_created': 1742852453,
#    'timestamp_updated': 1742852453,
#    'voted_up': True,
#    'votes_up': 3,
#    'votes_funny': 0,
#    'weighted_vote_score': '0.53248286247253418',
#    'comment_count': 0,
#    'steam_purchase': True,
#    'received_for_free': False,
#    'written_during_early_access': False,
#    'primarily_steam_deck': False},
#   {'recommendationid': '191124563',
#    'author': {'steamid': '76561198241791726',
#     'num_games_owned': 477,
#     'num_reviews': 26,
#     'playtime_forever': 82,
#     'playtime_last_two_weeks': 82,
#     'playtime_at_review': 82,
#     'last_played': 1742873671},
#    'language': 'english',
#    'review': 'I resumed from the demo ending. Its a souls like, but more Nioh than anything. Runs smooth, good graphics and gameplay is dope! If you cant git good, there is an easy mode for filthy casuals like me',
#    'timestamp_created': 1742874835,
#    'timestamp_updated': 1742875220,
#    'voted_up': True,
#    'votes_up': 1,
#    'votes_funny': 0,
#    'weighted_vote_score': '0.529411792755126953',
#    'comment_count': 0,
#    'steam_purchase': True,
#    'received_for_free': False,
#    'written_during_early_access': False,
#    'primarily_steam_deck': False},
#   {'recommendationid': '191137209',
#    'author': {'steamid': '76561199077127869',
#     'num_games_owned': 28,
#     'num_reviews': 22,
#     'playtime_forever': 281,
#     'playtime_last_two_weeks': 281,
#     'playtime_at_review': 86,
#     'last_played': 1742906672},
#    'language': 'english',
#    'review': 'The Art Direction, Sound Track, Movement, Combat, Boss designs, and world designs are all 10/10',
#    'timestamp_created': 1742894973,
#    'timestamp_updated': 1742894973,
#    'voted_up': True,
#    'votes_up': 2,
#    'votes_funny': 0,
#    'weighted_vote_score': '0.525862038135528564',
#    'comment_count': 0,
#    'steam_purchase': True,
#    'received_for_free': False,
#    'written_during_early_access': False,
#    'primarily_steam_deck': False},
#   {'recommendationid': '191134995',
#    'author': {'steamid': '76561198096821101',
#     'num_games_owned': 1597,
#     'num_reviews': 40,
#     'playtime_forever': 165,
#     'playtime_last_two_weeks': 165,
#     'playtime_at_review': 126,
#     'deck_playtime_at_review': 126,
#     'last_played': 1742893672},
#    'language': 'schinese',
# ...
#     'last_played': 1742920176},
#    'language': 'schinese',
#    'review': '主要是有中文配音在贵都买而且真的好玩',
#    'timestamp_created': 1742888039,
#    'timestamp_updated': 1742888039,
#    'voted_up': True,
#    'votes_up': 1,
#    'votes_funny': 0,
#    'weighted_vote_score': '0.503816783428192139',
#    'comment_count': 0,
#    'steam_purchase': True,
#    'received_for_free': False,
#    'written_during_early_access': False,
#    'primarily_steam_deck': False},
#   {'recommendationid': '191159859',
#    'author': {'steamid': '76561199510522111',
#     'num_games_owned': 111,
#     'num_reviews': 10,
#     'playtime_forever': 341,
#     'playtime_last_two_weeks': 341,
#     'playtime_at_review': 341,
#     'last_played': 1742915867},
#    'language': 'brazilian',
#    'review': 'Jogo foda demais, um dos combates mais satisfatorios que tá tendo',
#    'timestamp_created': 1742918803,
#    'timestamp_updated': 1742918803,
#    'voted_up': True,
#    'votes_up': 0,
#    'votes_funny': 0,
#    'weighted_vote_score': 0.5,
#    'comment_count': 0,
#    'steam_purchase': True,
#    'received_for_free': False,
#    'written_during_early_access': False,
#    'primarily_steam_deck': False},
#   {'recommendationid': '191159556',
#    'author': {'steamid': '76561198005737758',
#     'num_games_owned': 0,
#     'num_reviews': 25,
#     'playtime_forever': 743,
#     'playtime_last_two_weeks': 743,
#     'playtime_at_review': 713,
#     'last_played': 1742920629},
#    'language': 'koreana',
#    'review': '제법 매콤해요.\r\n\r\n원래 액션 게임 장르는 어렵지만\r\n이 게임은 나름 어려운 편입니다.\r\n\r\n혹여 이걸로 이 장르에 입문하실 생각이시라면\r\n다시 재고해 보시는 것이 좋을 것 같습니다.\r\n\r\n만약 액션 게임 유경험자이시고\r\n꽤 빡빡한 플레이를 좋아하신다면\r\n추천합니다.',
#    'timestamp_created': 1742918530,
#    'timestamp_updated': 1742918530,
#    'voted_up': True,
#    'votes_up': 0,
#    'votes_funny': 0,
#    'weighted_vote_score': 0.5,
#    'comment_count': 0,
#    'steam_purchase': True,
#    'received_for_free': False,
#    'written_during_early_access': False,
#    'primarily_steam_deck': False},
#   {'recommendationid': '191159259',
#    'author': {'steamid': '76561198212102992',
#     'num_games_owned': 0,
#     'num_reviews': 16,
#     'playtime_forever': 508,
#     'playtime_last_two_weeks': 508,
#     'playtime_at_review': 508,
#     'last_played': 1742917624},
#    'language': 'english',
#    'review': 'The demo is honestly what sold me on this game, gives a pretty good vertical slice of what to expect in the full game, so I would check that out if you\'re interested. Think Nioh meets Sekiro or Lies of P. Khazan\'s movement and kit feels very much like the combat of Nioh 2, even down to square/x and triiangle/y being your attack buttons. Parries (or Brink Guards) are super satisfying with a pretty generous window compared to other games. Same goes for "Brink Dodges" or perfect dodges. Dodging is completely viable if you aren\'t into parry based combat which I think is nice since it doesn\'t pidgeonhole the player into one playstyle. The different weapons are each fun in their own way, and each one offers a completely different playstyle. Enemy variety is good so far and quite different in each stage. Stages are also much like Nioh; mostly linear with a few branching paths that typically contain loot and/or minibosses. The bosses are absolutely peak thus far. Challenging, but fair, with very intuitive movesets and tells that make them a blast to fight against. The art style is also quite unique and even though its certainly in anime territory, it\'s very well done and the game looks stunning. All in all, a very well built game with no bugs or monetization which is surprising from Nexon, and just some of the best feeling combat I\'ve experienced. If you are a fan of any of the games I mentioned in this review, you will enjoy this game!',
#    'timestamp_created': 1742918292,
#    'timestamp_updated': 1742918292,
#    'voted_up': True,
#    'votes_up': 0,
#    'votes_funny': 0,
#    'weighted_vote_score': 0.5,
#    'comment_count': 0,
#    'steam_purchase': True,
#    'received_for_free': False,
#    'written_during_early_access': False,
#    'primarily_steam_deck': False},
#   {'recommendationid': '191159042',
#    'author': {'steamid': '76561199379624977',
#     'num_games_owned': 0,
#     'num_reviews': 8,
#     'playtime_forever': 948,
#     'playtime_last_two_weeks': 948,
#     'playtime_at_review': 948,
#     'last_played': 1742917977},
#    'language': 'schinese',
#    'review': '建议大家不是动作高手和有时间大量刷刷刷就别玩，这推图阴间就不说了，boss的数值就离谱，逼得你非要去刷才行，而且很多boss是必须背板，背板了还要去请援助才能勉强过。搞半天，原来你是缝合了魂和怪物猎人哦？',
#    'timestamp_created': 1742918111,
#    'timestamp_updated': 1742918111,
#    'voted_up': False,
#    'votes_up': 2,
#    'votes_funny': 1,
#    'weighted_vote_score': '0.520985424518585205',
#    'comment_count': 0,
#    'steam_purchase': True,
#    'received_for_free': False,
#    'written_during_early_access': False,
#    'primarily_steam_deck': False},
#   {'recommendationid': '191159019',
#    'author': {'steamid': '76561198105102916',
#     'num_games_owned': 0,
#     'num_reviews': 20,
#     'playtime_forever': 192,
#     'playtime_last_two_weeks': 192,
#     'playtime_at_review': 192,
#     'last_played': 1742916527},
#    'language': 'koreana',
#    'review': '오호 넥슨도 하면 되잔아\n를 느끼게해주네\n이것저것 섞긴 했는데 하고싶은 스타일로 하시면 됩니다.\n최적화 나름 잘한듯 몬헌와일즈 하다 이거하니 선녀로 보임\n스킬 초기화 무료니 이것저것 찍어보고 맞는 스타일로 세팅 가능 합니다.\n세키로 패링 맛이 생각나게 하는 저스트 가드 재미 있네\n1회차는 너로 정했다.',
#    'timestamp_created': 1742918092,
#    'timestamp_updated': 1742918092,
#    'voted_up': True,
#    'votes_up': 0,
#    'votes_funny': 0,
#    'weighted_vote_score': 0.5,
#    'comment_count': 0,
#    'steam_purchase': True,
#    'received_for_free': False,
#    'written_during_early_access': False,
#    'primarily_steam_deck': False},
#   {'recommendationid': '191158939',
#    'author': {'steamid': '76561199260721437',
#     'num_games_owned': 0,
#     'num_reviews': 18,
#     'playtime_forever': 346,
#     'playtime_last_two_weeks': 350,
#     'playtime_at_review': 285,
#     'last_played': 1742920591},
#    'language': 'english',
#    'review': 'STOP LEAVING BAD REVIEWS BECAUSE YOU HAVE A TRASH PC, anyways, I have been looking forward to this game and as a Souls/Soulslike/Bloodborne/Sekiro veteran, buy this, play it, let it consume you. 10/10',
#    'timestamp_created': 1742918030,
#    'timestamp_updated': 1742918030,
#    'voted_up': True,
#    'votes_up': 0,
#    'votes_funny': 0,
#    'weighted_vote_score': 0.5,
#    'comment_count': 0,
#    'steam_purchase': True,
#    'received_for_free': False,
#    'written_during_early_access': False,
#    'primarily_steam_deck': False},
#   {'recommendationid': '191158884',
#    'author': {'steamid': '76561198308677142',
#     'num_games_owned': 0,
#     'num_reviews': 3,
#     'playtime_forever': 96,
#     'playtime_last_two_weeks': 96,
#     'playtime_at_review': 96,
#     'last_played': 1742917581},
#    'language': 'koreana',
#    'review': '짧게 하긴했지만 이거는 소울류로 분류되기보다는 액션게임쪽으로 분류되는게 오히려 더 어울리지않나 생각한다. 난이도가 그렇게 난해하거나 어렵지 않으며 가드 타이밍도 생각보다 널널한편이고 회피또한 마찬가리고 생각보다 널널한편이다. 또 보스트라이를 실패하더라도 보스에게 준 피해량에 비례해 라크리마도 환급해주는거 같은데 이정도면 굉장히 배려를 해준편이라 생각한다. 사실 보스트라이하면서 렙업할려면 노가다를 좀 뛰어야하는게 소울류였는데 트라이만해도 어느정도는 환급해주니 말다한 샘. 무엇보다 죽더라도 라크리마에 다가가기만해도 회수되는걸 보며 이건 정말 잘만든 액션게임이라는 생각이 들었다.',
#    'timestamp_created': 1742917981,
#    'timestamp_updated': 1742917981,
#    'voted_up': True,
#    'votes_up': 0,
#    'votes_funny': 0,
#    'weighted_vote_score': 0.5,
#    'comment_count': 0,
#    'steam_purchase': True,
#    'received_for_free': False,
#    'written_during_early_access': False,
#    'primarily_steam_deck': False},
#   {'recommendationid': '191158346',
#    'author': {'steamid': '76561198215733125',
#     'num_games_owned': 0,
#     'num_reviews': 9,
#     'playtime_forever': 302,
#     'playtime_last_two_weeks': 302,
#     'playtime_at_review': 302,
#     'deck_playtime_at_review': 6,
#     'last_played': 1742917360},
#    'language': 'koreana',
#    'review': '넥슨이라 불안 했는데 게임은 재밋네요!!\r\n사실 애니메이션 그래픽보단 실사 그래픽을 좋아하는데 의외로 몰입이 잘 되었습니다.\r\n전투는 정말 괜찮습니다. 최적화 좋고 보는맛 좋고 저도 소울 잘하는 편이 아닌데 관심있으면 사서해보는것도 굿!!',
#    'timestamp_created': 1742917514,
#    'timestamp_updated': 1742917514,
#    'voted_up': True,
#    'votes_up': 0,
#    'votes_funny': 0,
#    'weighted_vote_score': 0.5,
#    'comment_count': 0,
#    'steam_purchase': True,
#    'received_for_free': False,
#    'written_during_early_access': False,
#    'primarily_steam_deck': False},
#   {'recommendationid': '191157411',
#    'author': {'steamid': '76561198882181831',
#     'num_games_owned': 0,
#     'num_reviews': 4,
#     'playtime_forever': 256,
#     'playtime_last_two_weeks': 256,
#     'playtime_at_review': 256,
#     'last_played': 1742914550},
#    'language': 'tchinese',
#    'review': '難度不高，我覺得很OK，加上還可調整簡單，那對非動作與魂系玩家來說應該更OK，打擊感也很強，畫風我覺得很讚，最重要的是有優化了，之前玩DEMO劇情還會跳偵，正式版完全沒有',
#    'timestamp_created': 1742916744,
#    'timestamp_updated': 1742916744,
#    'voted_up': True,
#    'votes_up': 0,
#    'votes_funny': 1,
#    'weighted_vote_score': 0.5,
#    'comment_count': 0,
#    'steam_purchase': True,
#    'received_for_free': False,
#    'written_during_early_access': False,
#    'primarily_steam_deck': False},
#   {'recommendationid': '191157269',
#    'author': {'steamid': '76561198066769032',
#     'num_games_owned': 149,
#     'num_reviews': 23,
#     'playtime_forever': 427,
#     'playtime_last_two_weeks': 427,
#     'playtime_at_review': 427,
#     'last_played': 1742882592},
#    'language': 'english',
#    'review': "It's like the Hades of souls-likes.  It feels extremely polished and runs pretty good.  Feedback is crisp.  Only three different weapons, but they do feel in-depth and thought out.  The combat feels like a slightly dumbed down Nioh 2, but has the blocking/deflect mechanic of Sekiro.  Khazan feels like a character that can go toe to toe with bosses whereas in elden ring or dark souls, you feel like a peasant going against gods and monsters.\n\nVisuals are clean, but the environments feel fairly repetitive.\n\nI'm only 7 hours in at the time of writing, but i'm not sure if it's worth $60+.  This is probably just Nexon feeling the waters on souls-likes so they can determine how hard to monetize Vindictus: Defying Fate.",
#    'timestamp_created': 1742916618,
#    'timestamp_updated': 1742916618,
#    'voted_up': True,
#    'votes_up': 0,
#    'votes_funny': 0,
#    'weighted_vote_score': 0.5,
#    'comment_count': 0,
#    'steam_purchase': True,
#    'received_for_free': False,
#    'written_during_early_access': False,
#    'primarily_steam_deck': False},
#   {'recommendationid': '191157235',
#    'author': {'steamid': '76561198010428515',
#     'num_games_owned': 0,
#     'num_reviews': 44,
#     'playtime_forever': 756,
#     'playtime_last_two_weeks': 756,
#     'playtime_at_review': 756,
#     'last_played': 1742914399},
#    'language': 'koreana',
#    'review': '지극히 주관적인 감상평\r\n\r\n진행을 얼마나 했는지 모르겠지만.. 보스 전투가 맛있네요\r\n\r\n쉬움으로 하면 기력에 대한 스트레스가 줄어들고 아마도 패링도 조금 더 쉬워지겠죠?\r\n\r\n일반으로 하더라도 크게 어려운건 못 느꼈습니다.. 아직까지는\r\n\r\n\r\n제작비가 얼마나 들어갔는지는 모르겠지만.. 부가 퀘스트 몬스터 재활용은 좀 아닌거 같긴 하다..\r\n\r\n그래도 기출변형으로 나와서 완전 똑같지는 않고요\r\n\r\n돈은 아까운 기분 전혀 안들었습니다',
#    'timestamp_created': 1742916588,
#    'timestamp_updated': 1742916588,
#    'voted_up': True,
#    'votes_up': 0,
#    'votes_funny': 0,
#    'weighted_vote_score': 0.5,
#    'comment_count': 0,
#    'steam_purchase': True,
#    'received_for_free': False,
#    'written_during_early_access': False,
#    'primarily_steam_deck': False},
#   {'recommendationid': '191156908',
#    'author': {'steamid': '76561198945514086',
#     'num_games_owned': 186,
#     'num_reviews': 15,
#     'playtime_forever': 233,
#     'playtime_last_two_weeks': 241,
#     'playtime_at_review': 142,
#     'last_played': 1742920265},
#    'language': 'english',
#    'review': 'Beautiful graphics, fun gameplay, instant respawns, lots of accessibility features, difficult but rewarding challenges.\nKhazan is also an Aura farmer, whats not to love?',
#    'timestamp_created': 1742916311,
#    'timestamp_updated': 1742916311,
#    'voted_up': True,
#    'votes_up': 0,
#    'votes_funny': 0,
#    'weighted_vote_score': 0.5,
#    'comment_count': 0,
#    'steam_purchase': True,
#    'received_for_free': False,
#    'written_during_early_access': False,
#    'primarily_steam_deck': False},
#   {'recommendationid': '191156289',
#    'author': {'steamid': '76561198375727539',
#     'num_games_owned': 0,
#     'num_reviews': 2,
#     'playtime_forever': 354,
#     'playtime_last_two_weeks': 354,
#     'playtime_at_review': 354,
#     'last_played': 1742915648},
#    'language': 'spanish',
#    'review': 'mecanicas muy satisfactorias y el juego me encanta la estetica y la historia',
#    'timestamp_created': 1742915790,
#    'timestamp_updated': 1742915790,
#    'voted_up': True,
#    'votes_up': 0,
#    'votes_funny': 0,
#    'weighted_vote_score': 0.5,
#    'comment_count': 0,
#    'steam_purchase': True,
#    'received_for_free': False,
#    'written_during_early_access': False,
#    'primarily_steam_deck': False},
#   {'recommendationid': '191156185',
#    'author': {'steamid': '76561199340244218',
#     'num_games_owned': 0,
#     'num_reviews': 1,
#     'playtime_forever': 310,
#     'playtime_last_two_weeks': 310,
#     'playtime_at_review': 310,
#     'last_played': 1742915611},
#    'language': 'schinese',
#    'review': '太好玩啦，兼顾画面和战斗的佳作',
#    'timestamp_created': 1742915718,
#    'timestamp_updated': 1742915718,
#    'voted_up': True,
#    'votes_up': 0,
#    'votes_funny': 0,
#    'weighted_vote_score': '0.490196079015731812',
#    'comment_count': 0,
#    'steam_purchase': True,
#    'received_for_free': False,
#    'written_during_early_access': False,
#    'primarily_steam_deck': False},
#   {'recommendationid': '191155769',
#    'author': {'steamid': '76561197996671841',
#     'num_games_owned': 446,
#     'num_reviews': 23,
#     'playtime_forever': 589,
#     'playtime_last_two_weeks': 589,
#     'playtime_at_review': 522,
#     'last_played': 1742919581},
#    'language': 'english',
#    'review': 'First impressions.\r\n\r\nSekiro-Nioh hybrid with 3 types of weapon movesets (DW, GS, Glaive).\r\n\r\nRequires perfect timed parry or dodge like Sekiro: otherwise you run out of stamina. Combat is much more methodical than Nioh, but animations/skills/combos are as fast as Nioh.\r\n\r\nBosses are very well designed, quite challenging at least early on (difficulty on par with Sekiro, early game Nioh. Much much much harder than Elden ring.) I killed all early~mid game Elden ring bosses in less than five tries, third main boss of this game took me an hour.',
#    'timestamp_created': 1742915394,
#    'timestamp_updated': 1742915394,
#    'voted_up': True,
#    'votes_up': 0,
#    'votes_funny': 0,
#    'weighted_vote_score': 0.5,
#    'comment_count': 0,
#    'steam_purchase': True,
#    'received_for_free': False,
#    'written_during_early_access': False,
#    'primarily_steam_deck': False},
#   {'recommendationid': '191155582',
#    'author': {'steamid': '76561198046663055',
#     'num_games_owned': 0,
#     'num_reviews': 8,
#     'playtime_forever': 241,
#     'playtime_last_two_weeks': 241,
#     'playtime_at_review': 241,
#     'last_played': 1742915147},
#    'language': 'english',
#    'review': 'Genuinely hype AF! loving the art, the combat flow, the skill tree is good but not overwhelming, THE WEAPONS ALL LOOK SO UNIQUE AND COOL AF!!!!!!',
#    'timestamp_created': 1742915245,
#    'timestamp_updated': 1742915245,
#    'voted_up': True,
#    'votes_up': 0,
#    'votes_funny': 0,
#    'weighted_vote_score': 0.5,
#    'comment_count': 0,
#    'steam_purchase': True,
#    'received_for_free': False,
#    'written_during_early_access': False,
#    'primarily_steam_deck': False},
#   {'recommendationid': '191155367',
#    'author': {'steamid': '76561198219739772',
#     'num_games_owned': 0,
#     'num_reviews': 2,
#     'playtime_forever': 181,
#     'playtime_last_two_weeks': 181,
#     'playtime_at_review': 130,
#     'last_played': 1742920620},
#    'language': 'koreana',
#    'review': '데모 이어서 진행했는데, 전투 손맛은 역시 본편에서도 이어지는듯\n\n리뷰영상들에서 아쉬운점들도 보여서 후반이 걱정이긴 한데, 전투자체만으로도 게임 즐기는 맛이 납니다.\n보스 반복사냥이 간편한것도 장점.. 데모때 블레이드팬텀세트 맞추고 싶었는데,\n드디어 완성했네요 아주 멋지고 좋았습니다.',
#    'timestamp_created': 1742915068,
#    'timestamp_updated': 1742915068,
#    'voted_up': True,
#    'votes_up': 0,
#    'votes_funny': 0,
#    'weighted_vote_score': 0.5,
#    'comment_count': 0,
#    'steam_purchase': True,
#    'received_for_free': False,
#    'written_during_early_access': False,
#    'primarily_steam_deck': False}],
#  'cursor': 'AoMFQFaAAAAAAAAFP+AAAAAAAAB3ypnZBQ=='}

# %%
a= save_reviews_to_csv(2680010)
a
# Out:
# Saved 200 reviews to ../Output/steam_reviews_2680010.csv
# '../Output/steam_reviews_2680010.csv'

# %%
results = process_reviews_for_keywords(csv_file=a,
        top_n=1000
        )

# %%
for result in results:
    print(result)
# Out:
# {'language': 'korean', 'keywords': []}
# {'language': 'english', 'keywords': [('game', 164), ('combat', 50), ('souls', 42), ('bosses', 31), ('boss', 25), ('fun', 25), ('games', 20), ('play', 20), ('feels', 19), ('demo', 19), ('skill', 18), ('art', 17), ('runs', 16), ('feel', 16), ('graphics', 16), ('easy', 16), ('weapon', 15), ('difficulty', 15), ('played', 14), ('parry', 14), ('story', 14), ('style', 14), ('lies', 13), ('gameplay', 13), ('weapons', 13), ('3', 13), ('running', 13), ('playing', 13), ('h1', 13), ('love', 13), ('lot', 12), ('stamina', 12), ('amazing', 12), ('time', 12), ('enjoy', 11), ('elden', 11), ('mechanics', 11), ('challenge', 11), ('smooth', 11), ('settings', 10), ('sekiro', 10), ('khazan', 10), ('pretty', 10), ('worth', 10), ('nioh', 10), ('recommend', 10), ('dark', 9), ('parrying', 9), ('super', 9), ('soulslike', 9), ('level', 9), ('gear', 9), ('anime', 9), ('challenging', 9), ('cool', 9), ('2', 8), ('fps', 8), ('awesome', 8), ('mode', 8), ('fan', 8), ('annoying', 7), ('skills', 7), ('perfect', 7), ('satisfying', 7), ('tree', 7), ('beautiful', 7), ('optimized', 7), ('people', 7), ('based', 6), ('100', 6), ('experience', 6), ('performance', 6), ('timing', 6), ('solid', 6), ('wait', 6), ('hard', 6), ('fast', 6), ('takes', 5), ('mission', 5), ('hit', 5), ('greatsword', 5), ('deluxe', 5), ('actual', 5), ('difficult', 5), ('4', 5), ('ass', 5), ('hp', 5), ('day', 5), ('damage', 5), ('reflection', 5), ('type', 5), ('enemy', 5), ('enemies', 5), ('character', 5), ('design', 5), ('highly', 5), ('smoothly', 5), ('release', 5), ('bought', 5), ('action', 5), ('genre', 5), ('loving', 5), ('loot', 5), ('1', 5), ('max', 5), ('normal', 5), ('gain', 4), ('die', 4), ('levels', 4), ('sound', 4), ('types', 4), ('120', 4), ('locked', 4), ('4k', 4), ('4080', 4), ('start', 4), ('punishing', 4), ('gpu', 4), ('attacks', 4), ('parries', 4), ('plays', 4), ('fluid', 4), ('5', 4), ('hour', 4), ('hooked', 4), ('gon', 4), ('huge', 4), ('sword', 4), ('window', 4), ('visuals', 4), ('loved', 4), ('beat', 4), ('learn', 4), ('learning', 4), ('enjoyable', 4), ('review', 4), ('progress', 4), ('nice', 4), ('hours', 4), ('players', 4), ('devs', 4), ('unique', 4), ('rage', 4), ('dfo', 4), ('absolutely', 3), ('runbacks', 3), ('lose', 3), ('ressources', 3), ('killing', 3), ('fight', 3), ('player', 3), ('change', 3), ('switch', 3), ('variety', 3), ('skillpoints', 3), ('armour', 3), ('experienced', 3), ('short', 3), ('access', 3), ('decent', 3), ('forgiving', 3), ('wukong', 3), ('set', 3), ('moves', 3), ('honest', 3), ('consumables', 3), ('upgrade', 3), ('healing', 3), ('stat', 3), ('personally', 3), ('basically', 3), ('spear', 3), ('stats', 3), ('extremely', 3), ('flow', 3), ('eyes', 3), ('money', 3), ('bit', 3), ('developers', 3), ('expect', 3), ('attack', 3), ('dodging', 3), ('stance', 3), ('designs', 3), ('responsive', 3), ('designed', 3), ('incredible', 3), ('optimization', 3), ('offers', 3), ('tough', 3), ('wow', 3), ('linear', 3), ('bugs', 3), ('battles', 3), ('nexon', 3), ('rewarding', 3), ('fair', 3), ('berserker', 3), ('fights', 3), ('surprised', 3), ('complete', 3), ('bad', 3), ('finished', 3), ('crazy', 3), ('pc', 3), ('literally', 2), ('starting', 2), ('trash', 2), ('mobs', 2), ('checkpoint', 2), ('died', 2), ('rewarded', 2), ('insanely', 2), ('fighting', 2), ('increase', 2), ('flawless', 2), ('ultra', 2), ('7800x3d', 2), ('tier', 2), ('improve', 2), ('steam', 2), ('deck', 2), ('oled', 2), ('amazingly', 2), ('refresh', 2), ('budget', 2), ('feedback', 2), ('windows', 2), ('stages', 2), ('yeah', 2), ('hope', 2), ('berserk', 2), ('hack', 2), ('slash', 2), ('unlocking', 2), ('dual', 2), ('update', 2), ('soundtracks', 2), ('combination', 2), ('viper', 2), ('true', 2), ('lost', 2), ('explore', 2), ('items', 2), ('capacity', 2), ('chapter', 2), ('single', 2), ('heals', 2), ('50', 2), ('rng', 2), ('upgrades', 2), ('bonuses', 2), ('pass', 2), ('axe', 2), ('stuck', 2), ('attempts', 2), ('overly', 2), ('adds', 2), ('health', 2), ('bigger', 2), ('return', 2), ('diminishing', 2), ('22', 2), ...

# %%
for result in results:
    generate_wordcloud(result['keywords'], result['language'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 2
#       1 for result in results:
# ----> 2     generate_wordcloud(result['keywords'], result['language'])
#
# Cell In[20], line 146, in generate_wordcloud(keywords, language)
#     137 def generate_wordcloud(keywords, language):
#     138     word_dict = dict(keywords)
#     139     wc = WordCloud(
#     140         font_path=FONT_PATH,
#     141         background_color=None, # 'white'
#     142         colormap='Set2',
#     143         mode='RGBA',
#     144         width=800,
#     145         height=400
# --> 146     ).generate_from_frequencies(word_dict)
#     148     csv_output_path = f"../Output/keyword_freq_{language}.csv"
#     149     pd.DataFrame(keywords, columns=['word', 'frequency']).to_csv(csv_output_path, index=False, encoding='utf-8-sig')
#
# File c:\Users\User\anaconda3\envs\myenv\Lib\site-packages\wordcloud\wordcloud.py:410, in WordCloud.generate_from_frequencies(self, frequencies, max_font_size)
#     408 frequencies = sorted(frequencies.items(), key=itemgetter(1), reverse=True)
#     409 if len(frequencies) <= 0:
# --> 410     raise ValueError("We need at least 1 word to plot a word cloud, "
#     411                      "got %d." % len(frequencies))
#     412 frequencies = frequencies[:self.max_words]
#     414 # largest entry will be 1
#
# ValueError: We need at least 1 word to plot a word cloud, got 0.
